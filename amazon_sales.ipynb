# %% [markdown]
# ## Amazon Product Sales Data Cleaning with Pandas

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("amazon_products_sales_data_uncleaned.csv")

# %%
df
# Out:
#                                                    title              rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
# ...                                                  ...                 ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...  5.0 out of 5 stars
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...  4.2 out of 5 stars
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...  4.3 out of 5 stars
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...  4.7 out of 5 stars
# 42674  Lorex Fusion 1080p HD Security Camera System w...  4.4 out of 5 stars
#
# ...

# %% [markdown]
# ## Inspection of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  object
#  2   number_of_reviews         41651 non-null  object
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  30926 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  buy_box_availability      28022 non-null  object
#  11  delivery_details          30955 non-null  object
#  12  sustainability_badges     3408 non-null   object
# ...

# %%
df.describe().round()
# Out:
#                                                     title              rating  \
# count                                               42675               41651
# unique                                               8808                  31
# top     Duracell Coppertop 9V Battery, 6 Count (Pack o...  4.6 out of 5 stars
# freq                                                  744                6151
#
#        number_of_reviews       bought_in_last_month current/discounted_price  \
# count              41651                      39458                    30926
# unique              4413                         59                     2576
# top                   25  100+ bought in past month                    29.99
# freq                 626                       8801                      825
#
#                 price_on_variant listed_price is_best_seller is_sponsored  \
# count                      42675        42675          42675        42675
# ...

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                       1024
# number_of_reviews            1024
# bought_in_last_month         3217
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# image_url                       0
# product_url                  2069
# collected_at                    0
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (0, 16)

# %%
df.shape
# Out:
# (42675, 16)

# %% [markdown]
# - droping images_url and product-url because they do not contribute to analytical insights

# %%
df = df.drop(["image_url","product_url"], axis=1)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'sustainability_badges', 'collected_at'],
#       dtype='object')

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# ##### Title

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'sustainability_badges', 'collected_at'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                       1024
# number_of_reviews            1024
# bought_in_last_month         3217
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# #### ratings

# %%
df["rating"].isnull().sum()
# Out:
# np.int64(1024)

# %%
df["rating"].unique()
# Out:
# array(['4.6 out of 5 stars', '4.3 out of 5 stars', '4.8 out of 5 stars',
#        '4.5 out of 5 stars', '4.0 out of 5 stars', '4.7 out of 5 stars',
#        '4.2 out of 5 stars', '4.4 out of 5 stars', '4.1 out of 5 stars',
#        '4.9 out of 5 stars', '3.9 out of 5 stars', '3.8 out of 5 stars',
#        '2.8 out of 5 stars', '3.6 out of 5 stars', '3.7 out of 5 stars',
#        '3.4 out of 5 stars', '3.5 out of 5 stars', nan,
#        '5.0 out of 5 stars', '3.3 out of 5 stars', '2.4 out of 5 stars',
#        '2.9 out of 5 stars', '3.2 out of 5 stars', '3.0 out of 5 stars',
#        '1.0 out of 5 stars', '2.3 out of 5 stars', '3.1 out of 5 stars',
#        '2.5 out of 5 stars', '2.7 out of 5 stars', '1.5 out of 5 stars',
#        '2.6 out of 5 stars', '2.0 out of 5 stars'], dtype=object)

# %%
df["rating"].describe()
# Out:
# count                  41651
# unique                    31
# top       4.6 out of 5 stars
# freq                    6151
# Name: rating, dtype: object

# %%
df["rating"].value_counts()
# Out:
# rating
# 4.6 out of 5 stars    6151
# 4.4 out of 5 stars    5525
# 4.5 out of 5 stars    5359
# 4.7 out of 5 stars    4664
# 4.8 out of 5 stars    4230
# 4.3 out of 5 stars    2927
# 4.2 out of 5 stars    2837
# 4.1 out of 5 stars    1959
# 4.0 out of 5 stars    1465
# 3.9 out of 5 stars    1316
# 3.8 out of 5 stars    1083
# 5.0 out of 5 stars     995
# 4.9 out of 5 stars     704
# 3.6 out of 5 stars     666
# 3.7 out of 5 stars     604
# 3.2 out of 5 stars     363
# 3.5 out of 5 stars     242
# 3.4 out of 5 stars     216
# 3.0 out of 5 stars     148
# 2.0 out of 5 stars     143
# 2.7 out of 5 stars      15
# 1.5 out of 5 stars      15
# 3.3 out of 5 stars       6
# 2.8 out of 5 stars       4
# 1.0 out of 5 stars       4
# 2.4 out of 5 stars       3
# 2.9 out of 5 stars       2
# 3.1 out of 5 stars       2
# 2.3 out of 5 stars       1
# 2.5 out of 5 stars       1
# 2.6 out of 5 stars       1
# Name: count, dtype: int64

# %%
df["rating"] = df['rating'].str.extract(r'(\d+\.\d+)').astype(float)

# %%
df["rating"] = df['rating'].fillna(df['rating'].median())

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews            1024
# bought_in_last_month         3217
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# ### number_of_reviews

# %%
df["number_of_reviews"].describe()
# Out:
# count     41651
# unique     4413
# top          25
# freq        626
# Name: number_of_reviews, dtype: object

# %%
df["number_of_reviews"].value_counts()
# Out:
# number_of_reviews
# 25        626
# 1         524
# 8         478
# 17        409
# 30        409
#          ...
# 48,468      1
# 72,360      1
# 67,965      1
# 53,340      1
# 8,962       1
# Name: count, Length: 4413, dtype: int64

# %%
df['number_of_reviews'].head(10)
# Out:
# 0       375
# 1     2,457
# 2     3,044
# 3    35,882
# 4    28,988
# 5    44,522
# 6    13,466
# 7    38,105
# 8     4,380
# 9     7,308
# Name: number_of_reviews, dtype: object

# %%
df['number_of_reviews'] = (
    df['number_of_reviews']
    .str.replace(',', '', regex=False)
    .astype(float)
)

# %%
df["number_of_reviews"].isnull().sum()
# Out:
# np.int64(1024)

# %%
df['number_of_reviews'].fillna(df["number_of_reviews"].median(), inplace=True)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_33652\1412695407.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_of_reviews'].fillna(df["number_of_reviews"].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month         3217
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# ### bought_in_last_month

# %%
df["bought_in_last_month"].head()
# Out:
# 0    300+ bought in past month
# 1     6K+ bought in past month
# 2     2K+ bought in past month
# 3    10K+ bought in past month
# 4    10K+ bought in past month
# Name: bought_in_last_month, dtype: object

# %%
df["bought_in_last_month"].unique()
# Out:
# array(['300+ bought in past month', '6K+ bought in past month',
#        '2K+ bought in past month', '10K+ bought in past month',
#        '100K+ bought in past month', nan, '100+ bought in past month',
#        '1K+ bought in past month', '500+ bought in past month',
#        '80K+ bought in past month', '70K+ bought in past month',
#        '50K+ bought in past month', '40K+ bought in past month',
#        '60K+ bought in past month', '20K+ bought in past month',
#        '30K+ bought in past month', '9K+ bought in past month',
#        '50+ bought in past month', '5K+ bought in past month',
#        'List Price:', '7K+ bought in past month',
#        '4K+ bought in past month', 'Typical:',
#        '200+ bought in past month', '8K+ bought in past month',
#        'ESRB Rating: Everyone', '3K+ bought in past month',
#        'No featured offers available', 'List:',
#        'ESRB Rating: Rating Pending', '900+ bought in past month',
# ...

# %%
import numpy as np

def clean_bought(x):
    if pd.isna(x):
        return np.nan

    x = str(x)

    if 'bought in past month' in x:
        num = x.split('+')[0]

        if 'K' in num:
            return float(num.replace('K', '')) * 1000

        return float(num)

    return np.nan

df['bought_in_last_month'] = df['bought_in_last_month'].apply(clean_bought)

# %%
df['bought_in_last_month'].isnull().sum()
# Out:
# np.int64(10511)

# %%
df['bought_in_last_month'].fillna(
    df['bought_in_last_month'].median(),
    inplace=True
)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_33652\1699490390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bought_in_last_month'].fillna(

# %%
df['bought_in_last_month'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month            0
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# ### current/discounted_price

# %%
df['current/discounted_price'].unique()
# Out:
# array(['89.68', '9.99', '314.00', ..., '1,579.99', '20.14', '1,252.29'],
#       dtype=object)

# %%
df['current/discounted_price'].describe()
# Out:
# count     30926
# unique     2576
# top       29.99
# freq        825
# Name: current/discounted_price, dtype: object

# %%
df['current/discounted_price'] = pd.to_numeric(df['current/discounted_price'].str.replace(",",""), errors='coerce')

# %%
df['current/discounted_price'].fillna(df['current/discounted_price'].median(), inplace=True)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_33652\1749864171.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['current/discounted_price'].fillna(df['current/discounted_price'].median(), inplace=True)

# %%
df['current/discounted_price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month            0
# current/discounted_price        0
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# #### buy_box_availabilty

# %%
df['buy_box_availability'].isnull().sum()
# Out:
# np.int64(14653)

# %%
df['buy_box_availability'].unique()
# Out:
# array(['Add to cart', nan], dtype=object)

# %%
df['buy_box_availability'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: buy_box_availability
# Non-Null Count  Dtype
# --------------  -----
# 28022 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['buy_box_availability'].value_counts()
# Out:
# buy_box_availability
# Add to cart    28022
# Name: count, dtype: int64

# %%
df['buy_box_availability'].fillna("Unknown",inplace=True)
# Out:
# C:\Users\akhil\AppData\Local\Temp\ipykernel_33652\660643703.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['buy_box_availability'].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month            0
# current/discounted_price        0
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability            0
# delivery_details            11720
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# ### delivery_details

# %%
df['delivery_details'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: delivery_details
# Non-Null Count  Dtype
# --------------  -----
# 30955 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['delivery_details'].unique()
# Out:
# array(['Delivery Mon, Sep 1', 'Delivery Fri, Aug 29', nan,
#        'Delivery Sep 1 - 11', 'Delivery Sep 4 - 9', 'Delivery Sep 8 - 30',
#        'Delivery Aug 28 - Sep 1', 'Delivery Sep 1 - 2',
#        'Delivery Aug 28 - Sep 3', 'Delivery Sep 1 - 9',
#        'Delivery Aug 29 - Sep 2', 'Delivery Sep 9 - 25',
#        'Delivery Aug 29 - Sep 12', 'Delivery Sep 1 - 3',
#        '$42.19 delivery', 'Delivery Tue, Sep 2', 'Delivery Sep 1 - 4',
#        'Delivery Sep 1 - 12', 'Delivery Aug 29 - Sep 3',
#        'Delivery Sep 3 - 11', 'Delivery Sep 3 - 15', '$41.20 delivery',
#        '$40.35 delivery', 'Delivery Sep 1 - 8', 'Delivery Aug 29 - Sep 4',
#        'Delivery Sep 3 - 23', 'Ships to Pakistan', '$73.42 delivery',
#        '$40.34 delivery', 'Delivery Sep 8 - 26', '$58.05 delivery',
#        'Delivery Sep 8 - 25', '$40.13 delivery', '$43.43 delivery',
#        'Delivery Sep 8 - Oct 7', 'Delivery Sep 8 - 24',
#        'Delivery Sep 22 - Nov 4', '$40.89 delivery', '$44.08 delivery',
# ...

# %%
df['delivery_details'].describe()
# Out:
# count                   30955
# unique                    298
# top       Delivery Mon, Sep 1
# freq                     6189
# Name: delivery_details, dtype: object

# %%
df['delivery_details'].isnull().sum()
# Out:
# np.int64(11720)

# %%
df['delivery_details'] = df['delivery_details'].str.extract(r'Delivery\s+(.*)')

# %% [markdown]
# - Forward fill was used because nearby records had similar delivery information. In a production environment, this decision should be validated with domain knowledge.

# %%
df['delivery_details'] = df['delivery_details'].ffill()

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month            0
# current/discounted_price        0
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability            0
# delivery_details                0
# sustainability_badges       39267
# collected_at                    0
# dtype: int64

# %% [markdown]
# ### sustainabilty_badges

# %%
df['sustainability_badges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: sustainability_badges
# Non-Null Count  Dtype
# --------------  -----
# 3408 non-null   object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['sustainability_badges'].describe()
# Out:
# count               3408
# unique                16
# top       Small Business
# freq                1341
# Name: sustainability_badges, dtype: object

# %%
df['sustainability_badges'].unique()
# Out:
# array(['Carbon impact', nan, 'Energy efficiency',
#        'Safer chemicals +1 more', 'Small Business',
#        '1 sustainability certification', 'Works with Alexa',
#        'Manufacturing practices', 'Forestry practices', 'Alexa Built-in',
#        'Energy efficiency +3 more', 'Recycled materials',
#        'Safer chemicals +2 more', 'Energy efficiency +1 more',
#        'Recycled materials +3 more', 'Recycled materials +2 more',
#        'Made in Italy'], dtype=object)

# %%
df.drop('sustainability_badges', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# title                       0
# rating                      0
# number_of_reviews           0
# bought_in_last_month        0
# current/discounted_price    0
# price_on_variant            0
# listed_price                0
# is_best_seller              0
# is_sponsored                0
# is_couponed                 0
# buy_box_availability        0
# delivery_details            0
# collected_at                0
# dtype: int64

# %% [markdown]
# ### fixing Inconsitent formating

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df[df.duplicated()].shape
# Out:
# (0, 13)

# %%
df['title'].unique()
# Out:
# array(['BOYA BOYALINK 2 Wireless Lavalier Microphone for iPhone Camera Android, Mini Lapel Micophone Wireless, 48 KHz 24 Bit, 6mm Mic, 1000ft, 30h Use, Noise Cancelling, Clip on Mic USB-C/Lightning/3.5mm TRS',
#        'LISEN USB C to Lightning Cable, 240W 4 in 1 Charging Cable 6.6FT, Chubby USB A/C to C/Lightning with Light for iPhone 16e 15 14 Pro/MacBook Air 17/iPad/Samsung/Switch 2, Multi Chargers for All Devices',
#        'DJI Mic 2 (2 TX + 1 RX + Charging Case), Wireless Lavalier Microphone, Intelligent Noise Cancelling, 32-bit Float Internal Recording, 820 ft.(250m) Range, Microphone for iPhone, Android, Camera',
#        ...,
#        'Monster Clarity 8.0 Hybrid Active Noise Cancelling Wireless Earbuds, 42dB in-Ear ANC Earphones Deep Bass with 6 Mics, Bluetooth 5.2, 50H Play Time with Wireless Charging Case,Blue',
#        'Audio-Technica HP-EP Replacement Ear Pads for M Series Headphones',
# ...

# %%
df['title'] = df['title'].str.strip()

# %%
df['title'] = df['title'].str.lower()

# %%
df['title'].duplicated().sum()
# Out:
# np.int64(33868)

# %%
df['title'].value_counts()
# Out:
# title
# duracell coppertop 9v battery, 6 count (pack of 1), 9 volt battery with long-lasting power, all-purpose alkaline 9v battery for household and office devices                                               744
# energizer max aa batteries (16 pack), double a alkaline batteries                                                                                                                                          566
# trx training 6 month on-demand membership - unlimited access to expert-led workouts, personalized programs, strength, cardio & recovery - train anytime                                                    456
# kodak 10.1 inch wifi digital picture frame,1280x800 hd ips touch screen, electronic smart photo frame with 32 gb memory, auto-rotate, instantly share photos/videos anywhere                               438
# ...

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  float64
# dtypes: float64(1)
# memory usage: 333.5 KB

# %%
df['rating'].describe()
# Out:
# count    42675.000000
# mean         4.401844
# std          0.382636
# min          1.000000
# 25%          4.200000
# 50%          4.500000
# 75%          4.600000
# max          5.000000
# Name: rating, dtype: float64

# %%
df['rating'].head(20)
# Out:
# 0     4.6
# 1     4.3
# 2     4.6
# 3     4.6
# 4     4.8
# 5     4.6
# 6     4.5
# 7     4.6
# 8     4.0
# 9     4.7
# 10    4.7
# 11    4.8
# 12    4.2
# 13    4.4
# 14    4.7
# 15    4.7
# 16    4.8
# 17    4.7
# 18    4.8
# 19    4.6
# Name: rating, dtype: float64

# %%
df['number_of_reviews'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['number_of_reviews'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  float64
# dtypes: float64(1)
# memory usage: 333.5 KB

# %%
df['number_of_reviews'].head(20)
# Out:
# 0        375.0
# 1       2457.0
# 2       3044.0
# 3      35882.0
# 4      28988.0
# 5      44522.0
# 6      13466.0
# 7      38105.0
# 8       4380.0
# 9       7308.0
# 10    865598.0
# 11      1914.0
# 12       152.0
# 13     12076.0
# 14      7235.0
# 15     48468.0
# 16    198512.0
# 17    625776.0
# 18     88965.0
# 19      1909.0
# Name: number_of_reviews, dtype: float64

# %%
df['number_of_reviews'].nunique()
# Out:
# 4413

# %%
df['number_of_reviews'] = df['number_of_reviews'].astype('int64')

# %%
(df['number_of_reviews'] < 0).sum()
# Out:
# np.int64(0)

# %%
df['bought_in_last_month'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bought_in_last_month'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: bought_in_last_month
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  float64
# dtypes: float64(1)
# memory usage: 333.5 KB

# %%
df['bought_in_last_month'].unique()
# Out:
# array([3.e+02, 6.e+03, 2.e+03, 1.e+04, 1.e+05, 2.e+02, 1.e+02, 1.e+03,
#        5.e+02, 8.e+04, 7.e+04, 5.e+04, 4.e+04, 6.e+04, 2.e+04, 3.e+04,
#        9.e+03, 5.e+01, 5.e+03, 7.e+03, 4.e+03, 8.e+03, 3.e+03, 9.e+02,
#        4.e+02, 7.e+02, 8.e+02, 6.e+02, 9.e+04])

# %%
df['bought_in_last_month'].value_counts()
# Out:
# bought_in_last_month
# 200.0       16156
# 100.0        8801
# 50.0         5967
# 300.0        2842
# 500.0        2351
# 1000.0       2084
# 400.0        1436
# 20000.0       772
# 2000.0        426
# 800.0         280
# 3000.0        249
# 600.0         229
# 10000.0       229
# 4000.0        196
# 5000.0        120
# 700.0         102
# 90000.0        92
# 6000.0         81
# 900.0          63
# 7000.0         49
# 9000.0         44
# 8000.0         36
# 30000.0        28
# 40000.0        14
# 100000.0       13
# 50000.0         6
# 70000.0         4
# 60000.0         3
# 80000.0         2
# Name: count, dtype: int64

# %%
df['bought_in_last_month'].head(20)
# Out:
# 0        300.0
# 1       6000.0
# 2       2000.0
# 3      10000.0
# 4      10000.0
# 5     100000.0
# 6      10000.0
# 7      10000.0
# 8        200.0
# 9      10000.0
# 10    100000.0
# 11     10000.0
# 12       100.0
# 13      1000.0
# 14       500.0
# 15    100000.0
# 16     80000.0
# 17    100000.0
# 18    100000.0
# 19     10000.0
# Name: bought_in_last_month, dtype: float64

# %%
(df['bought_in_last_month'] % 1 != 0).sum()
# Out:
# np.int64(0)

# %%
df['bought_in_last_month'] = df['bought_in_last_month'].astype('int64')

# %%
df['bought_in_last_month'].head(20)
# Out:
# 0        300
# 1       6000
# 2       2000
# 3      10000
# 4      10000
# 5     100000
# 6      10000
# 7      10000
# 8        200
# 9      10000
# 10    100000
# 11     10000
# 12       100
# 13      1000
# 14       500
# 15    100000
# 16     80000
# 17    100000
# 18    100000
# 19     10000
# Name: bought_in_last_month, dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['current/discounted_price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['current/discounted_price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: current/discounted_price
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  float64
# dtypes: float64(1)
# memory usage: 333.5 KB

# %%
df['current/discounted_price'].unique()
# Out:
# array([  89.68,    9.99,  314.  , ..., 1579.99,   20.14, 1252.29])

# %%
df['current/discounted_price'].value_counts()
# Out:
# current/discounted_price
# 77.00     11883
# 29.99       825
# 119.99      695
# 13.99       585
# 24.99       502
#           ...
# 212.36        1
# 882.99        1
# 9.89          1
# 188.06        1
# 18.79         1
# Name: count, Length: 2576, dtype: int64

# %%
df['current/discounted_price'].head(20)
# Out:
# 0      89.68
# 1       9.99
# 2     314.00
# 3      77.00
# 4      77.00
# 5      77.00
# 6      77.00
# 7      77.00
# 8      16.99
# 9      77.00
# 10     14.99
# 11     77.00
# 12     29.99
# 13    249.99
# 14     69.95
# 15     77.00
# 16     39.97
# 17     14.49
# 18     16.98
# 19     77.00
# Name: current/discounted_price, dtype: float64

# %%
(df['current/discounted_price'] < 0).sum()
# Out:
# np.int64(0)

# %%
df['price_on_variant'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: price_on_variant
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['price_on_variant'].unique()
# Out:
# array(['basic variant price: 2.4GHz', 'basic variant price: nan',
#        'basic variant price: $162.24', ...,
#        'basic variant price: $33.00 off coupon applied',
#        'basic variant price: $112.96', 'basic variant price: $1,054.05'],
#       dtype=object)

# %%
df['price_on_variant'].value_counts()
# Out:
# price_on_variant
# basic variant price: nan                          21031
# basic variant price: 16 Count (Pack of 1)           582
# basic variant price: $9.99                          324
# basic variant price: $119.95                        298
# basic variant price: $169.99                        264
#                                                   ...
# basic variant price: $90.00 off coupon applied        1
# basic variant price: $880.95                          1
# basic variant price: $88.11                           1
# basic variant price: $23.04                           1
# basic variant price: $13.88                           1
# Name: count, Length: 3466, dtype: int64

# %%
df['price_on_variant'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['price_on_variant'].head(20)
# Out:
# 0      basic variant price: 2.4GHz
# 1         basic variant price: nan
# 2         basic variant price: nan
# 3     basic variant price: $162.24
# 4      basic variant price: $72.74
# 5      basic variant price: $99.95
# 6      basic variant price: $88.11
# 7      basic variant price: $23.04
# 8         basic variant price: nan
# 9     basic variant price: $284.05
# 10        basic variant price: nan
# 11    basic variant price: $880.95
# 12        basic variant price: nan
# 13        basic variant price: nan
# 14        basic variant price: nan
# 15     basic variant price: $17.45
# 16     basic variant price: $38.86
# 17        basic variant price: nan
# 18     basic variant price: $13.88
# 19     basic variant price: $33.51
# Name: price_on_variant, dtype: object

# %%
df['price_on_variant'] = (
    df['price_on_variant']
    .str.extract(r'\$([\d,]+\.?\d*)')[0]
    .str.replace(',', '', regex=False)
)

df['price_on_variant'] = pd.to_numeric(
    df['price_on_variant'],
    errors='coerce'
)

# %%
df['price_on_variant'].head(20)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3     162.24
# 4      72.74
# 5      99.95
# 6      88.11
# 7      23.04
# 8        NaN
# 9     284.05
# 10       NaN
# 11    880.95
# 12       NaN
# 13       NaN
# 14       NaN
# 15     17.45
# 16     38.86
# 17       NaN
# 18     13.88
# 19     33.51
# Name: price_on_variant, dtype: float64

# %%
df['price_on_variant'].isnull().sum()
# Out:
# np.int64(22604)

# %%
df['price_on_variant'].isnull().mean() * 100
# Out:
# np.float64(52.96777973052138)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['listed_price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['listed_price'].unique()
# Out:
# array(['$159.00', '$15.99', '$349.00', 'No Discount', '$19.98', '$14.33',
#        '$17.99', '$21.89', '$20.00', '$48.99', '$19.99', '$38.98',
#        '$14.39', '$169.99', '$29.99', '$219.99', '$15.00', '$24.99',
#        '$32.72', '$71.87', '$18.99', '$21.44', '$199.99', '$99.95',
#        '$79.99', '$49.99', '$33.99', '$39.99', '$89.99', '$119.97',
#        '$35.64', '$24.58', '$69.99', '$249.99', '$27.99', '$6.29',
#        '$239.99', '$229.99', '$169.00', '$32.29', '$34.99', '$348.00',
#        '$65.99', '$5.84', '$176.99', '$96.99', '$11.87', '$43.29',
#        '$64.99', '$159.95', '$45.79', '$109.99', '$8.99', '$32.99',
#        '$149.99', '$25.99', '$339.99', '$99.99', '$35.99', '$449.00',
#        '$76.99', '$165.00', '$13.33', '$7.79', '$30.00', '$129.99',
#        '$22.99', '$78.00', '$719.00', '$299.89', '$175.00', '$299.99',
#        '$25.00', '$199.95', '$97.99', '$21.98', '$86.99', '$24.49',
#        '$439.99', '$61.99', '$17.14', '$10.70', '$399.00', '$21.99',
# ...

# %%
df['listed_price'].head(20)
# Out:
# 0         $159.00
# 1          $15.99
# 2         $349.00
# 3     No Discount
# 4     No Discount
# 5     No Discount
# 6     No Discount
# 7     No Discount
# 8     No Discount
# 9     No Discount
# 10    No Discount
# 11    No Discount
# 12    No Discount
# 13    No Discount
# 14    No Discount
# 15    No Discount
# 16    No Discount
# 17    No Discount
# 18    No Discount
# 19    No Discount
# Name: listed_price, dtype: object

# %%
df['listed_price'].value_counts()
# Out:
# listed_price
# No Discount    30364
# $79.99           500
# $29.99           406
# $16.61           360
# $23.26           283
#                ...
# $42.50             1
# $2,999.99          1
# $16.97             1
# $71.87             1
# $14.33             1
# Name: count, Length: 911, dtype: int64

# %%
df['listed_price'] = df['listed_price'].str.extract(r'\$([\d,]+\.?\d*)')[0].str.replace(",","",regex=False)

# %%
df['listed_price'] = pd.to_numeric(df['listed_price'], errors='coerce')

# %%
df['listed_price'].isnull().sum()
# Out:
# np.int64(30364)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'is_best_seller', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['is_best_seller'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: is_best_seller
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['is_best_seller'].value_counts()
# Out:
# is_best_seller
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %%
df['is_best_seller'].head(20)
# Out:
# 0        No Badge
# 1        No Badge
# 2        No Badge
# 3     Best Seller
# 4        No Badge
# 5     Best Seller
# 6        No Badge
# 7     Best Seller
# 8        No Badge
# 9     Best Seller
# 10    Best Seller
# 11    Best Seller
# 12       No Badge
# 13       No Badge
# 14       No Badge
# 15    Best Seller
# 16    Best Seller
# 17    Best Seller
# 18    Best Seller
# 19       No Badge
# Name: is_best_seller, dtype: object

# %%
df['is_best_seller'].unique()
# Out:
# array(['No Badge', 'Best Seller', "Amazon's", 'Limited time deal',
#        'Save 30%', 'Save 12%', 'Save 9%', 'Save 17%', 'Save 77%',
#        'Ends in', 'Save 10%', 'Save 18%'], dtype=object)

# %%
df.rename(columns={'is_best_seller': 'badge_type'}, inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'is_couponed', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['badge_type'] = df['badge_type'].str.strip()

# %%
df['badge_type'].value_counts()
# Out:
# badge_type
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %%
df['is_sponsored'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['is_sponsored'].unique()
# Out:
# array(['Sponsored', 'Organic'], dtype=object)

# %%
df['is_sponsored'].value_counts()
# Out:
# is_sponsored
# Organic      35664
# Sponsored     7011
# Name: count, dtype: int64

# %%
df['is_sponsored'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: is_sponsored
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['is_sponsored'].head(20)
# Out:
# 0     Sponsored
# 1     Sponsored
# 2     Sponsored
# 3       Organic
# 4       Organic
# 5       Organic
# 6       Organic
# 7       Organic
# 8       Organic
# 9       Organic
# 10      Organic
# 11      Organic
# 12    Sponsored
# 13    Sponsored
# 14    Sponsored
# 15      Organic
# 16      Organic
# 17      Organic
# 18      Organic
# 19      Organic
# Name: is_sponsored, dtype: object

# %%
df['is_couponed'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: is_couponed
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['is_couponed'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['is_couponed'].unique()
# Out:
# array(['Save 15%  with coupon', 'No Coupon', 'Save 50%  with coupon',
#        'Save $16.00  with coupon', 'Save $10.00  with coupon',
#        'Save 10%  with coupon', 'Save $20.00  with coupon',
#        'Save $4.00  with coupon', 'Save $0.33  with coupon',
#        'Save $18.00  with coupon', 'Save 5%  with coupon',
#        'Save $2.00  with coupon', 'Save $15.00  with coupon',
#        'Save 6%  with coupon', 'Save $8.00  with coupon',
#        'Save $40.00  with coupon', 'Save $1.50  with coupon',
#        'Save 7%  with coupon', 'Save 20%  with coupon',
#        'Save $1.00  with coupon', 'Save $5.00  with coupon',
#        'Save $30.00  with coupon', 'Save $12.00  with coupon',
#        'Save 25%  with coupon', 'Save $133.00  with coupon',
#        'Save $50.00  with coupon', 'Save $11.00  with coupon',
#        'Save 30%  with coupon', 'Save $3.00  with coupon',
#        'Save 40%  with coupon', 'Save $25.00  with coupon',
#        'Save $13.00  with coupon',
# ...

# %%
df['is_couponed'].value_counts()
# Out:
# is_couponed
# No Coupon                                    40727
# Save $16.00  with coupon                       438
# Save 15%  with coupon                          398
# Save 10%  with coupon                          218
# Save 5%  with coupon                           191
# Save 50%  with coupon                          123
# Save $11.00  with coupon                       120
# Save $100.00  with coupon                       97
# Save 40%  with coupon                           96
# Save $25.00  with coupon                        65
# Save $30.00  with coupon                        49
# Save $69.00  with coupon                        31
# Save 8%  with coupon                            18
# Save $10.00  with coupon                        14
# Save $33.00  with coupon                        13
# Save 20%  with coupon                            9
# Save $20.00  with coupon                         9
# Save $18.00  with coupon                         8
# ...

# %%
df.rename(columns={"is_couponed":"couponed_info"},inplace=True)

# %%
df['couponed_info'] = df['couponed_info'].str.replace(r'\s+', ' ', regex=True)

# %%
df['couponed_info'] = df['couponed_info'].str.strip()

# %%
df['couponed_info'].unique()
# Out:
# array(['Save 15% with coupon', 'No Coupon', 'Save 50% with coupon',
#        'Save $16.00 with coupon', 'Save $10.00 with coupon',
#        'Save 10% with coupon', 'Save $20.00 with coupon',
#        'Save $4.00 with coupon', 'Save $0.33 with coupon',
#        'Save $18.00 with coupon', 'Save 5% with coupon',
#        'Save $2.00 with coupon', 'Save $15.00 with coupon',
#        'Save 6% with coupon', 'Save $8.00 with coupon',
#        'Save $40.00 with coupon', 'Save $1.50 with coupon',
#        'Save 7% with coupon', 'Save 20% with coupon',
#        'Save $1.00 with coupon', 'Save $5.00 with coupon',
#        'Save $30.00 with coupon', 'Save $12.00 with coupon',
#        'Save 25% with coupon', 'Save $133.00 with coupon',
#        'Save $50.00 with coupon', 'Save $11.00 with coupon',
#        'Save 30% with coupon', 'Save $3.00 with coupon',
#        'Save 40% with coupon', 'Save $25.00 with coupon',
#        'Save $13.00 with coupon',
# ...

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'couponed_info', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['buy_box_availability'].unique()
# Out:
# array(['Add to cart', 'Unknown'], dtype=object)

# %%
df['buy_box_availability'].value_counts()
# Out:
# buy_box_availability
# Add to cart    28022
# Unknown        14653
# Name: count, dtype: int64

# %%
df['buy_box_availability'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['buy_box_availability'].head()
# Out:
# 0    Add to cart
# 1    Add to cart
# 2    Add to cart
# 3        Unknown
# 4        Unknown
# Name: buy_box_availability, dtype: object

# %%
df['buy_box_availability'] = df['buy_box_availability'].str.strip()

# %%
df['buy_box_availability'].head(20)
# Out:
# 0     Add to cart
# 1     Add to cart
# 2     Add to cart
# 3         Unknown
# 4         Unknown
# 5         Unknown
# 6         Unknown
# 7         Unknown
# 8         Unknown
# 9         Unknown
# 10    Add to cart
# 11        Unknown
# 12    Add to cart
# 13    Add to cart
# 14    Add to cart
# 15        Unknown
# 16    Add to cart
# 17    Add to cart
# 18    Add to cart
# 19        Unknown
# Name: buy_box_availability, dtype: object

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'couponed_info', 'buy_box_availability',
#        'delivery_details', 'collected_at'],
#       dtype='object')

# %%
df['delivery_details'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 42675 entries, 0 to 42674
# Series name: delivery_details
# Non-Null Count  Dtype
# --------------  -----
# 42675 non-null  object
# dtypes: object(1)
# memory usage: 333.5+ KB

# %%
df['delivery_details'].unique()
# Out:
# array(['Mon, Sep 1', 'Fri, Aug 29', 'Sep 1 - 11', 'Sep 4 - 9',
#        'Sep 8 - 30', 'Aug 28 - Sep 1', 'Sep 1 - 2', 'Aug 28 - Sep 3',
#        'Sep 1 - 9', 'Aug 29 - Sep 2', 'Sep 9 - 25', 'Aug 29 - Sep 12',
#        'Sep 1 - 3', 'Tue, Sep 2', 'Sep 1 - 4', 'Sep 1 - 12',
#        'Aug 29 - Sep 3', 'Sep 3 - 11', 'Sep 3 - 15', 'Sep 1 - 8',
#        'Aug 29 - Sep 4', 'Sep 3 - 23', 'Sep 8 - 26', 'Sep 8 - 25',
#        'Sep 8 - Oct 7', 'Sep 8 - 24', 'Sep 22 - Nov 4', 'Aug 27 - Sep 1',
#        'Sep 8 - 23', 'Sep 1 - 17', 'Sep 8 - 22', 'Sep 2 - 11',
#        'Sep 4 - 25', 'Sep 5 - 16', 'Aug 29 - Sep 11', 'Sep 8 - 17',
#        'Sep 2 - 9', 'Sep 10 - 24', 'Sep 9 - 26', 'Sep 15 - 26',
#        'Sep 8 - 16', 'Sep 9 - 16', 'Sep 2 - 15', 'Aug 28 - Sep 2',
#        'Sep 9 - 23', 'Sep 15 - 30', 'Sep 5 - 15', 'Sep 3 - 9',
#        'Sep 5 - 29', 'Sep 16 - Oct 3', 'Sep 8 - Oct 1', 'Sep 4 - 12',
#        'Sep 17 - Oct 28', 'Fri, Sep 19', 'Sep 8 - 19', 'Sep 8 - 18',
# ...

# %%
df['delivery_details'].value_counts()
# Out:
# delivery_details
# Thu, Sep 11                                  13200
# Mon, Sep 1                                    8306
# Thu, Sep 4                                    6293
# Tue, Sep 2                                    4742
# Tue, Sep 9                                    3239
#                                              ...
# Sep 19 - Oct 1                                   1
# Mon, Sep 8Or fastest delivery Thu, Aug 28        1
# Sep 8 - 10                                       1
# Sep 11 - Oct 9                                   1
# Mon, Sep 8Or fastest delivery Wed, Sep 3         1
# Name: count, Length: 136, dtype: int64

# %%
df['delivery_date'] = df['delivery_details'].str.extract(
    r'([A-Za-z]{3},?\s[A-Za-z]{3}\s\d{1,2}|\b[A-Za-z]{3}\s\d{1,2})'
)

# %%
df['delivery_range'] = df['delivery_details'].str.extract(
    r'(\d{1,2}\s*-\s*[A-Za-z]{3}\s*\d{1,2}|\b[A-Za-z]{3}\s\d{1,2}\s*-\s*\d{1,2})'
)

# %%
df['delivery_date'] = df['delivery_date'].str.strip()
df['delivery_range'] = df['delivery_range'].str.strip()

# %%
df.drop(columns=['delivery_details'], inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'couponed_info', 'buy_box_availability',
#        'collected_at', 'delivery_date', 'delivery_range'],
#       dtype='object')

# %%
df['delivery_date'].unique()
# Out:
# array(['Mon, Sep 1', 'Fri, Aug 29', 'Sep 1', 'Sep 4', 'Sep 8', 'Aug 28',
#        'Aug 29', 'Sep 9', 'Tue, Sep 2', 'Sep 3', 'Sep 22', 'Aug 27',
#        'Sep 2', 'Sep 5', 'Sep 10', 'Sep 15', 'Sep 16', 'Sep 17',
#        'Fri, Sep 19', 'Mon, Sep 8', 'Sep 12', 'Thu, Sep 11', 'Thu, Sep 4',
#        'Fri, Sep 5', 'Thu, Aug 28', 'Fri, Sep 12', 'Wed, Sep 10',
#        'Tue, Sep 9', 'Wed, Sep 3', 'Sep 19', 'Sep 11', 'Mon, Sep 15',
#        'Sun, Aug 31', 'Sep 29'], dtype=object)

# %%
df['delivery_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['delivery_range'].unique()
# Out:
# array([nan, 'Sep 1 - 11', 'Sep 4 - 9', 'Sep 8 - 30', '28 - Sep 1',
#        'Sep 1 - 2', '28 - Sep 3', 'Sep 1 - 9', '29 - Sep 2', 'Sep 9 - 25',
#        '29 - Sep 12', 'Sep 1 - 3', 'Sep 1 - 4', 'Sep 1 - 12',
#        '29 - Sep 3', 'Sep 3 - 11', 'Sep 3 - 15', 'Sep 1 - 8',
#        '29 - Sep 4', 'Sep 3 - 23', 'Sep 8 - 26', 'Sep 8 - 25',
#        '8 - Oct 7', 'Sep 8 - 24', '22 - Nov 4', '27 - Sep 1',
#        'Sep 8 - 23', 'Sep 1 - 17', 'Sep 8 - 22', 'Sep 2 - 11',
#        'Sep 4 - 25', 'Sep 5 - 16', '29 - Sep 11', 'Sep 8 - 17',
#        'Sep 2 - 9', 'Sep 10 - 24', 'Sep 9 - 26', 'Sep 15 - 26',
#        'Sep 8 - 16', 'Sep 9 - 16', 'Sep 2 - 15', '28 - Sep 2',
#        'Sep 9 - 23', 'Sep 15 - 30', 'Sep 5 - 15', 'Sep 3 - 9',
#        'Sep 5 - 29', '16 - Oct 3', '8 - Oct 1', 'Sep 4 - 12',
#        '17 - Oct 28', 'Sep 8 - 19', 'Sep 8 - 18', 'Sep 5 - 23',
#        '28 - Sep 4', '8 - Oct 3', '9 - Oct 3', 'Sep 15 - 29',
#        'Sep 4 - 16', '15 - Oct 24', 'Sep 8 - 29', 'Sep 2 - 4',
# ...

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'couponed_info', 'buy_box_availability',
#        'collected_at', 'delivery_date', 'delivery_range'],
#       dtype='object')

# %%
df['collected_at'].unique()
# Out:
# array(['2025-08-21 11:14:29', '2025-08-21 11:14:46',
#        '2025-08-21 11:14:47', ..., '2025-08-30 19:55:04',
#        '2025-08-30 19:55:28', '2025-08-30 19:56:33'], dtype=object)

# %%
df['collected_at'].value_counts()
# Out:
# collected_at
# 2025-08-21 11:15:31    33
# 2025-08-21 11:15:58    33
# 2025-08-21 11:14:29    33
# 2025-08-21 11:16:09    33
# 2025-08-30 19:53:37    33
#                        ..
# 2025-08-29 11:22:29     1
# 2025-08-27 08:04:15     1
# 2025-08-27 07:39:48     1
# 2025-08-24 22:26:13     1
# 2025-08-21 12:07:49     1
# Name: count, Length: 1559, dtype: int64

# %%
df['collected_at'] = pd.to_datetime(df['collected_at'])

# %%
df['title'].head()
# Out:
# 0    boya boyalink 2 wireless lavalier microphone f...
# 1    lisen usb c to lightning cable, 240w 4 in 1 ch...
# 2    dji mic 2 (2 tx + 1 rx + charging case), wirel...
# 3    apple airpods pro 2 wireless earbuds, active n...
# 4    apple airtag 4 pack. keep track of and find yo...
# Name: title, dtype: object

# %% [markdown]
# ### Handling Duplicates

# %%
df[df.duplicated()].shape
# Out:
# (0, 14)

# %%
df['title'].duplicated().sum()
# Out:
# np.int64(33868)

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'price_on_variant', 'listed_price',
#        'badge_type', 'is_sponsored', 'couponed_info', 'buy_box_availability',
#        'collected_at', 'delivery_date', 'delivery_range'],
#       dtype='object')

# %% [markdown]
# ### Correcting datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    42675 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      42675 non-null  int64
#  4   current/discounted_price  42675 non-null  float64
#  5   price_on_variant          20071 non-null  float64
#  6   listed_price              12311 non-null  float64
#  7   badge_type                42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   couponed_info             42675 non-null  object
#  10  buy_box_availability      42675 non-null  object
#  11  collected_at              42675 non-null  datetime64[ns]
#  12  delivery_date             42675 non-null  object
# ...

# %%
df['badge_type'] = df['badge_type'].astype('category')
df['is_sponsored'] = df['is_sponsored'].astype('category')
df['couponed_info'] = df['couponed_info'].astype('category')
df['buy_box_availability'] = df['buy_box_availability'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    42675 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      42675 non-null  int64
#  4   current/discounted_price  42675 non-null  float64
#  5   price_on_variant          20071 non-null  float64
#  6   listed_price              12311 non-null  float64
#  7   badge_type                42675 non-null  category
#  8   is_sponsored              42675 non-null  category
#  9   couponed_info             42675 non-null  category
#  10  buy_box_availability      42675 non-null  category
#  11  collected_at              42675 non-null  datetime64[ns]
#  12  delivery_date             42675 non-null  object
# ...

# %% [markdown]
# ## final validation

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                          0
# number_of_reviews               0
# bought_in_last_month            0
# current/discounted_price        0
# price_on_variant            22604
# listed_price                30364
# badge_type                      0
# is_sponsored                    0
# couponed_info                   0
# buy_box_availability            0
# collected_at                    0
# delivery_date                   0
# delivery_range              40470
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    42675 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      42675 non-null  int64
#  4   current/discounted_price  42675 non-null  float64
#  5   price_on_variant          20071 non-null  float64
#  6   listed_price              12311 non-null  float64
#  7   badge_type                42675 non-null  category
#  8   is_sponsored              42675 non-null  category
#  9   couponed_info             42675 non-null  category
#  10  buy_box_availability      42675 non-null  category
#  11  collected_at              42675 non-null  datetime64[ns]
#  12  delivery_date             42675 non-null  object
# ...

# %%
memory_after = df.memory_usage(deep=True).sum()/1024**2
print(memory_after)
# Out:
# 14.922701835632324

# %%
df.to_csv(
    "amazon_products_sales_data_cleaned.csv",
    index=False
)
